# %%
from sklearn.datasets import load_iris
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt
iris = load_iris()
X = iris.data
y = iris.target
tsne = TSNE(n_components=2, random_state=42)
X_embedded = tsne.fit_transform(X)
print("The Graph Plotted")
plt.scatter(X_embedded[:,0], X_embedded[:,1], c=y)
plt.show()
# Out:
# The Graph Plotted

# %%
from sklearn.datasets import fetch_california_housing
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
data = fetch_california_housing()
df = pd.DataFrame(data.data, columns=data.feature_names)
df["Price"] = data.target
print("The Graph Plotted")
sns.pairplot(df.sample(200))
plt.show()
# Out:
# The Graph Plotted

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
df = pd.read_csv("Data Resources/nyc_temperature.csv")
X = df[["Year"]]
y = df["Temperature"]
model = LinearRegression()
model.fit(X, y)
pred = model.predict(X)
print("The Graph Plotted")
plt.scatter(df["Year"], y)
plt.plot(df["Year"], pred)
plt.show()
# Out:
# The Graph Plotted

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
iris = load_iris()
X_train, X_test, y_train, y_test = train_test_split(
    iris.data, iris.target, test_size=0.2, random_state=42
)
model = KNeighborsClassifier()
model.fit(X_train, y_train)
print("The Model Score: ",model.score(X_test, y_test))
# Out:
# The Model Score:  1.0

# %%
import math
points = {
    "A": ((2.0, 3.0), 0),
    "B": ((1.0, 1.0), 0),
    "C": ((4.0, 4.0), 1),
    "D": ((5.0, 2.0), 1)
}
p = (3.0, 3.0)
distances = []
for name, value in points.items():
    point, label = value
    d = math.sqrt((point[0]-p[0])**2 + (point[1]-p[1])**2)
    distances.append((d, label))
distances.sort()
k = 3
neighbors = distances[:k]
result = round(sum(label for _, label in neighbors) / k)
print("The Result For KNN: ",result)
# Out:
# The Result For KNN:  1

# %%
import math
X = [
    [85, 90, 88],
    [70, 75, 80],
    [60, 65, 70],
    [50, 55, 58],
    [95, 92, 96],
    [45, 50, 48]
]
y = ["Pass", "Pass", "Fail", "Fail", "Pass", "Fail"]
new = [72, 78, 75]
distances = []
for i in range(len(X)):
    d = math.sqrt(sum((X[i][j]-new[j])**2 for j in range(3)))
    distances.append((d, y[i]))
distances.sort()
neighbors = distances[:3]
labels = [label for _, label in neighbors]
print("The Result: ",max(set(labels), key=labels.count))
# Out:
# The Result:  Pass

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import KFold, cross_val_score
from sklearn.neighbors import KNeighborsClassifier
iris = load_iris()
X = iris.data
y = iris.target
kf = KFold(n_splits=5, shuffle=True, random_state=42)
best_k = 1
best_score = 0
for k in range(1, 21):
    model = KNeighborsClassifier(n_neighbors=k)
    scores = cross_val_score(model, X, y, cv=kf)
    mean_score = scores.mean()
    if mean_score > best_score:
        best_score = mean_score
        best_k = k
print("The Best K: ",best_k)
print("The Best K-Score: ",best_score)
# Out:
# The Best K:  13
# The Best K-Score:  0.9800000000000001

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
X = np.array([[1,1],[2,2],[3,3],[8,8],[9,9],[10,10]])
model = KMeans(n_clusters=2, random_state=42)
labels = model.fit_predict(X)
print("The Graph Plotted")
plt.scatter(X[:,0], X[:,1], c=labels)
plt.scatter(model.cluster_centers_[:,0], model.cluster_centers_[:,1], s=200)
plt.show()
# Out:
# The Graph Plotted

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
df = pd.read_csv("Data Resources/Mall_Customers.csv")
X = df.iloc[:, [3,4]].values
wcss = []
for i in range(1, 11):
    km = KMeans(n_clusters=i, random_state=42)
    km.fit(X)
    wcss.append(km.inertia_)
plt.plot(range(1,11), wcss)
plt.show()
model = KMeans(n_clusters=5, random_state=42)
labels = model.fit_predict(X)
print("The Graph Plotted")
plt.scatter(X[:,0], X[:,1], c=labels)
plt.scatter(model.cluster_centers_[:,0], model.cluster_centers_[:,1], s=200)
plt.show()
# Out:
# The Graph Plotted

# %%
## 10(a)
import pandas as pd
s = pd.Series([7, 11, 13, 17])
print(s)
print("10(a) Completed\n")

## 10(b)
import pandas as pd
s = pd.Series([100.0] * 5)
print(s)
print("10(b) Completed\n")

## 10(c)
import pandas as pd
import numpy as np
s = pd.Series(np.random.randint(0, 101, 20))
print(s)
print(s.describe())
print("10(c) Completed\n")

## 10(d)
import pandas as pd
temperatures = pd.Series(
    [98.6, 98.9, 100.2, 97.9],
    index=["Julie", "Charlie", "Sam", "Andrea"]
)
print(temperatures)
print("10(d) Completed\n")

## 10(e)
import pandas as pd
data = {
    "Julie": 98.6,
    "Charlie": 98.9,
    "Sam": 100.2,
    "Andrea": 97.9
}
s = pd.Series(data)
print(s)
print("10(e) Completed\n")
# Out:
# 0     7
# 1    11
# 2    13
# 3    17
# dtype: int64
# 10(a) Completed
#
# 0    100.0
# 1    100.0
# 2    100.0
# 3    100.0
# 4    100.0
# dtype: float64
# 10(b) Completed
#
# 0     92
# 1     99
# 2      3
# 3     27
# 4     23
# 5     35
# 6     46
# 7      7
# 8     95
# 9     79
# 10    25
# 11    91
# 12    46
# 13    14
# 14    36
# 15    95
# 16    93
# 17    54
# 18    84
# 19    16
# dtype: int32
# count    20.000000
# mean     53.000000
# std      34.354192
# min       3.000000
# 25%      24.500000
# 50%      46.000000
# 75%      91.250000
# max      99.000000
# dtype: float64
# 10(c) Completed
#
# Julie       98.6
# Charlie     98.9
# Sam        100.2
# Andrea      97.9
# dtype: float64
# 10(d) Completed
#
# Julie       98.6
# Charlie     98.9
# Sam        100.2
# Andrea      97.9
# dtype: float64
# 10(e) Completed
