# %%
a=(x for x in 'ABCDE')
print(a)
print(list(a))
# Out:
# <generator object <genexpr> at 0x000001C36948D3C0>
# ['A', 'B', 'C', 'D', 'E']

# %%
for i in range(1,6):
    if (i==1 or i==5):
        print("* "*5)
    else:
        print("* "," "*3," *")
# Out:
# * * * * *
# *       *
# *       *
# *       *
# * * * * *

# %%
for i in [1,2,3,4]:
    print(i,end=",")
a,b=input("Enter Name: ").split()
print(f"\nThe name is: {a}, {b}")
# Out:
# 1,2,3,4,The name is: Amulya, Deep
