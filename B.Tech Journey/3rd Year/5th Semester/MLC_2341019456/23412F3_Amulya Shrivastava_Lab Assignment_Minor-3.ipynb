# %% [markdown]
# ### Lab Assignments-3
#
# **Name** - Amulya Shrivastava
# **Registration Number** - 2341019456
# **Section** - 23412F3
# **Serial Number** - 59

# %% [markdown]
# Question-1
#
# In order to assess the performance of students of a class in the annual examination, the class teacher stored marks of the students in all the 5 subjects in a CSV “Marks.csv” file as shown in Table. Plot the data using boxplot and perform a comparative analysis of performance in each subject.

# %%
import pandas as pd
import matplotlib.pyplot as plt
data=pd.read_csv("Data/Marks.csv")
subjects=['Maths','English','Hindi','Science','Social Studies']
marks=data[subjects]
plt.figure(figsize=(10,6))
plt.boxplot(marks.values,tick_labels=subjects)
plt.title("Each Subject Comparison")
plt.ylabel("Marks")
plt.show()

# %% [markdown]
# Question-2
#
# Prayatna sells designer bags and wallets. During the sales season, he gave discounts ranging from 10% to 50% over a period of 5 weeks. He recorded his sales for each type of discount in an array. Draw a scatter plot to show a relationship between the discount offered and sales made.

# %%
import matplotlib.pyplot as plt
discounts=[10,20,30,40,50]
sales=[100,150,200,250,300]
plt.scatter(discounts,sales,color='blue')
plt.title("Discount VS Sales")
plt.xlabel("Discount")
plt.ylabel("Sales")
plt.show()

# %% [markdown]
# Question-3
#
# Analyze and visualize automobile fuel efficiency Auto MPG dataset using `pandas` for data manipulation and `matplotlib` for plotting.
#
# Dataset URL: `http://archive.ics.uci.edu/ml/machine-learning-databases/auto-mpg/auto-mpg.data`
#
# Column Names: ['mpg', 'cylinders', 'displacement', 'horsepower', 'weight','acceleration', 'model_year', 'origin', 'car_name']

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# Question 3(a)
#
# Data Loading and Cleaning
# - Load the dataset using `pandas`.
# - Assign proper column names.
# - Handle missing values (hint: some rows have '?' in the `horsepower` column).
# - Convert the `horsepower` column to numeric type.

# %%
import pandas as pd
url="http://archive.ics.uci.edu/ml/machine-learning-databases/auto-mpg/auto-mpg.data"
columns=['mpg','cylinders','displacement','horsepower','weight','acceleration','model_year','origin','car_name']
data=pd.read_csv(url,names=columns,sep=r'\s+',na_values='?')
data["horsepower"]=pd.to_numeric(data["horsepower"])
data=data.dropna()

# %% [markdown]
# Question 3(b)
#
# Scatter Plot: Horsepower vs MPG
# - Create a scatter plot showing the relationship between “horsepower” and “mpg”.
# - Label the axes and title the plot appropriately.
# - Use grid lines for better readability.

# %%
plt.scatter(data["horsepower"],data["mpg"])
plt.xlabel("Horsepower")
plt.ylabel("MPG")
plt.title("Horsepower VS MPG")
plt.grid(True)
plt.show()

# %% [markdown]
# Question 3(c)
#
# Histogram: Distribution of MPG
# - Plot a histogram to show the frequency distribution of the `mpg` (miles per gallon).
# - Use appropriate number of bins (e.g., 15–20).
# - Label the axes and add a title.

# %%
plt.hist(data["mpg"],bins=15,edgecolor="black")
plt.xlabel("MPG")
plt.ylabel("Frequency")
plt.title("MPG Distribution")
plt.show()

# %% [markdown]
# Question 3(d)
#
# Box Plot: (MPG by Cylinders)
# - Create a box plot showing the distribution of “mpg” grouped by the number of “cylinders”.
# - Each box should represent one cylinder group (e.g., 4, 6, 8).
# - Add axis labels and a title.

# %%
data.boxplot(column="mpg",by="cylinders")
plt.xlabel("Cylinders")
plt.ylabel("MPG")
plt.title("MPG Vs No Of Cylinders")
plt.suptitle("")
plt.show()
