# %%
import numpy as np
from scipy.stats import bernoulli
p=0.6
x=np.array([0, 1])
pmf1=[1-p,p]
cdf1=[1-p,1]
print("Manual PMF:",pmf1)
print("Manual CDF:",cdf1)
check=bernoulli(p)
pmf2=check.pmf(x)
cdf2=check.cdf(x)
print("SciPy PMF:",pmf2)
print("SciPy CDF:",cdf2)
# Out:
# Manual PMF: [0.4, 0.6]
# Manual CDF: [0.4, 1]
# SciPy PMF: [0.4 0.6]
# SciPy CDF: [0.4 1. ]

# %%
import numpy as np
from scipy.stats import binom
import matplotlib.pyplot as plt
n=10
p=0.4
x=np.arange(0,n+1)
pmf=binom.pmf(x,n,p)
cdf=binom.cdf(5,n,p)
print("PMF values ( 1-",n,"): ",end="")
for i, val in zip(x,pmf):
    print(f"{val:.4f}",end=" ")
print("\nCDF for X<=5:",round(cdf,4))
x=range(n+1)
plt.bar(x,pmf)
plt.title("Graph show")
plt.show()
# Out:
# PMF values ( 1- 10 ): 0.0060 0.0403 0.1209 0.2150 0.2508 0.2007 0.1115 0.0425 0.0106 0.0016 0.0001
# CDF for X<=5: 0.8338

# %%
import numpy as np
from scipy.stats import poisson
assign=3
x=np.arange(0,11)
pmf=poisson.pmf(x,assign)
cdf=poisson.cdf(4,assign)
print("PMF values ( 1-",n,"): ",end="")
for i, val in zip(x,pmf):
    print(f"{val:.4f}",end=" ")
print("\nCDF for x<=4:",round(cdf,4))
# Out:
# PMF values ( 1- 10 ): 0.0498 0.1494 0.2240 0.2240 0.1680 0.1008 0.0504 0.0216 0.0081 0.0027 0.0008
# CDF for x<=4: 0.8153

# %%
import numpy as np
import matplotlib.pyplot as plt
store=np.random.uniform(2,8,size=100)
x=np.linspace(2,8,100)
pdf=np.ones(100)/6
plt.hist(store, bins=20)
plt.plot(x, pdf)
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.title('Graph Plot')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm
meu=50
sigma=10
x=60
pdf=norm.pdf(x,meu,sigma)
cdf=norm.cdf(x,meu,sigma)
print("The PDF value is:",round(pdf,5))
print("The CDF value is:",round(cdf,5))
plt.scatter(x,pdf)
plt.title("Graph")
plt.xlabel("x")
plt.ylabel("PDF")
plt.show()
# Out:
# The PDF value is: 0.0242
# The CDF value is: 0.84134

# %%
from sklearn.naive_bayes import GaussianNB
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score,precision_score,recall_score,f1_score,confusion_matrix
X=np.array([[1, 2],[1, 3],[2, 2],[2, 3]])
y=np.array([0, 0, 1, 1])
x_train,x_test,y_train,y_test=train_test_split(X,y,test_size=0.25,random_state=42)
model=GaussianNB()
model.fit(x_train, y_train)
y_predict = model.predict(x_test)
print("Accuracy=",accuracy_score(y_test,y_predict))
print("Precision=",precision_score(y_test,y_predict))
print("Recall=",recall_score(y_test,y_predict))
print("F1 score=",f1_score(y_test,y_predict))
print("Confusion matrix=",confusion_matrix(y_test,y_predict))
# Out:
# Accuracy= 1.0
# Precision= 0.0
# Recall= 0.0
# F1 score= 0.0
# Confusion matrix= [[1]]
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1757: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
